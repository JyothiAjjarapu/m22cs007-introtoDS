# %%
import pandas as pd

# Replace 'dataset.csv' with the actual file path of your CSV dataset
file_path = r'C:\Users\jyoth\OneDrive\Desktop\Mtech Sem3\Courses\Intro to DS\2\covid_vaccine_statewise.csv'

# Load the CSV dataset into a Pandas DataFrame
data = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to verify the data has been loaded
data.head()
# Out:
#    Updated On  State  Total Individuals Vaccinated  Total Sessions Conducted  \
# 0  16/01/2021  India                       48276.0                    3455.0
# 1  17/01/2021  India                       58604.0                    8532.0
# 2  18/01/2021  India                       99449.0                   13611.0
# 3  19/01/2021  India                      195525.0                   17855.0
# 4  20/01/2021  India                      251280.0                   25472.0
#
#    Total Sites   First Dose Administered  Second Dose Administered  \
# 0        2957.0                  48276.0                       0.0
# 1        4954.0                  58604.0                       0.0
# 2        6583.0                  99449.0                       0.0
# 3        7951.0                 195525.0                       0.0
# 4       10504.0                 251280.0                       0.0
#
#    Male(Individuals Vaccinated)  Female(Individuals Vaccinated)  \
# 0                       23757.0                         24517.0
# 1                       27348.0                         31252.0
# 2                       41361.0                         58083.0
# 3                       81901.0                        113613.0
# 4                       98111.0                        153145.0
#
#    Transgender(Individuals Vaccinated)  Total Covaxin Administered  \
# 0                                  2.0                       579.0
# 1                                  4.0                       635.0
# 2                                  5.0                      1299.0
# 3                                 11.0                      3017.0
# 4                                 24.0                      3946.0
#
#    Total CoviShield Administered  AEFI  18-30 years (Age)  30-45 years (Age)  \
# 0                        47697.0   NaN                NaN                NaN
# 1                        57969.0   NaN                NaN                NaN
# 2                        98150.0   NaN                NaN                NaN
# 3                       192508.0   NaN                NaN                NaN
# 4                       247334.0   NaN                NaN                NaN
#
#    45-60 years (Age)  60+ years (Age)  Total Doses Administered
# 0                NaN              NaN                   48276.0
# 1                NaN              NaN                   58604.0
# 2                NaN              NaN                   99449.0
# 3                NaN              NaN                  195525.0
# 4                NaN              NaN                  251280.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
jyothi_df2 = pd.read_csv(file_path)

# %%
jyothi_df2
# Out:
#       Updated On        State  Total Individuals Vaccinated  \
# 0     16/01/2021        India                       48276.0
# 1     17/01/2021        India                       58604.0
# 2     18/01/2021        India                       99449.0
# 3     19/01/2021        India                      195525.0
# 4     20/01/2021        India                      251280.0
# ...          ...          ...                           ...
# 4435  11/05/2021  West Bengal                     8862487.0
# 4436  12/05/2021  West Bengal                     8890679.0
# 4437  13/05/2021  West Bengal                     8916777.0
# 4438  14/05/2021  West Bengal                     8929070.0
# 4439  15/05/2021  West Bengal                     8955081.0
#
#       Total Sessions Conducted  Total Sites   First Dose Administered  \
# 0                       3455.0        2957.0                  48276.0
# 1                       8532.0        4954.0                  58604.0
# 2                      13611.0        6583.0                  99449.0
# 3                      17855.0        7951.0                 195525.0
# 4                      25472.0       10504.0                 251280.0
# ...                        ...           ...                      ...
# 4435                  273890.0        1560.0                8862487.0
# 4436                  290220.0        1693.0                8890679.0
# 4437                  252139.0        1473.0                8916777.0
# 4438                  207632.0        1145.0                8929070.0
# 4439                  265500.0        1535.0                8955081.0
#
#       Second Dose Administered  Male(Individuals Vaccinated)  \
# 0                          0.0                       23757.0
# 1                          0.0                       27348.0
# 2                          0.0                       41361.0
# 3                          0.0                       81901.0
# 4                          0.0                       98111.0
# ...                        ...                           ...
# 4435                 3364391.0                     4763561.0
# 4436                 3517391.0                     4779701.0
# 4437                 3645913.0                     4795315.0
# 4438                 3680177.0                     4803397.0
# 4439                 3717988.0                     4820673.0
#
#       Female(Individuals Vaccinated)  Transgender(Individuals Vaccinated)  \
# 0                            24517.0                                  2.0
# 1                            31252.0                                  4.0
# 2                            58083.0                                  5.0
# 3                           113613.0                                 11.0
# 4                           153145.0                                 24.0
# ...                              ...                                  ...
# 4435                       4097909.0                               1017.0
# 4436                       4109958.0                               1020.0
# 4437                       4120439.0                               1023.0
# 4438                       4124650.0                               1023.0
# 4439                       4133379.0                               1029.0
#
#       Total Covaxin Administered  Total CoviShield Administered    AEFI  \
# 0                          579.0                        47697.0     NaN
# 1                          635.0                        57969.0     NaN
# 2                         1299.0                        98150.0     NaN
# 3                         3017.0                       192508.0     NaN
# 4                         3946.0                       247334.0     NaN
# ...                          ...                            ...     ...
# 4435                   1325190.0                     10901688.0  1033.0
# 4436                   1350173.0                     11057897.0  1033.0
# 4437                   1372847.0                     11189843.0  1034.0
# 4438                   1381997.0                     11227250.0  1034.0
# 4439                   1395568.0                     11277501.0  1034.0
#
#       18-30 years (Age)  30-45 years (Age)  45-60 years (Age)  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 4435           282991.0           814971.0          3989225.0
# 4436           285689.0           820096.0          4000085.0
# 4437           288514.0           826151.0          4009986.0
# 4438           290362.0           830873.0          4013500.0
# 4439           293620.0           839189.0          4023691.0
#
#       60+ years (Age)  Total Doses Administered
# 0                 NaN                   48276.0
# 1                 NaN                   58604.0
# 2                 NaN                   99449.0
# 3                 NaN                  195525.0
# 4                 NaN                  251280.0
# ...               ...                       ...
# 4435        3774405.0                12226878.0
# 4436        3783870.0                12408070.0
# 4437        3791146.0                12562690.0
# 4438        3793337.0                12609247.0
# 4439        3797563.0                       NaN
#
# [4440 rows x 18 columns]

# %%
jyothi_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4440 entries, 0 to 4439
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Updated On                           4440 non-null   object
#  1   State                                4440 non-null   object
#  2   Total Individuals Vaccinated         4403 non-null   float64
#  3   Total Sessions Conducted             4403 non-null   float64
#  4   Total Sites                          4403 non-null   float64
#  5   First Dose Administered              4403 non-null   float64
#  6   Second Dose Administered             4403 non-null   float64
#  7   Male(Individuals Vaccinated)         4403 non-null   float64
#  8   Female(Individuals Vaccinated)       4403 non-null   float64
#  9   Transgender(Individuals Vaccinated)  4403 non-null   float64
#  10  Total Covaxin Administered           4403 non-null   float64
#  11  Total CoviShield Administered        4403 non-null   float64
#  12  AEFI                                 2201 non-null   float64
#  13  18-30 years (Age)                    2201 non-null   float64
#  14  30-45 years (Age)                    2201 non-null   float64
#  15  45-60 years (Age)                    2201 non-null   float64
#  16  60+ years (Age)                      2201 non-null   float64
#  17  Total Doses Administered             4403 non-null   float64
# dtypes: float64(16), object(2)
# memory usage: 624.5+ KB

# %%
jyothi_df2.describe()
# Out:
#        Total Individuals Vaccinated  Total Sessions Conducted  Total Sites   \
# count                  4.403000e+03              4.403000e+03   4403.000000
# mean                   2.767474e+06              2.363641e+05   2417.364297
# std                    1.170086e+07              9.729221e+05   7759.111316
# min                    7.000000e+00              0.000000e+00      0.000000
# 25%                    4.351850e+04              1.930000e+03     67.000000
# 50%                    2.455440e+05              1.158300e+04    581.000000
# 75%                    1.766746e+06              1.495025e+05   1842.000000
# max                    1.411321e+08              1.078696e+07  73933.000000
#
#        First Dose Administered  Second Dose Administered  \
# count             4.403000e+03              4.403000e+03
# mean              2.751247e+06              5.334889e+05
# std               1.169048e+07              2.482765e+06
# min               7.000000e+00              0.000000e+00
# 25%               4.146950e+04              1.170000e+02
# 50%               2.388030e+05              3.490800e+04
# 75%               1.713403e+06              3.339295e+05
# max               1.411321e+08              4.041242e+07
#
#        Male(Individuals Vaccinated)  Female(Individuals Vaccinated)  \
# count                  4.403000e+03                    4.403000e+03
# mean                   1.447784e+06                    1.319363e+06
# std                    6.128544e+06                    5.572637e+06
# min                    0.000000e+00                    2.000000e+00
# 25%                    2.210050e+04                    2.024250e+04
# 50%                    1.184850e+05                    1.180430e+05
# 75%                    9.438170e+05                    8.381335e+05
# max                    7.432438e+07                    6.678792e+07
#
#        Transgender(Individuals Vaccinated)  Total Covaxin Administered  \
# count                          4403.000000                4.403000e+03
# mean                            346.184193                3.013273e+05
# std                            1506.745611                1.329288e+06
# min                               0.000000                0.000000e+00
# 25%                               2.000000                0.000000e+00
# 50%                              21.000000                4.070000e+02
# 75%                             233.000000                1.735590e+05
# max                           19812.000000                1.853531e+07
#
#        Total CoviShield Administered          AEFI  18-30 years (Age)  \
# count                   4.403000e+03   2201.000000       2.201000e+03
# mean                    2.963895e+06    998.698319       1.619396e+05
# std                     1.277872e+07   2981.808856       5.753053e+05
# min                     7.000000e+00      0.000000       8.500000e+01
# 25%                     4.514650e+04     88.000000       5.195000e+03
# 50%                     2.573340e+05    273.000000       3.749700e+04
# 75%                     1.886489e+06    635.000000       1.316500e+05
# max                     1.630092e+08  20459.000000       7.447446e+06
#
#        30-45 years (Age)  45-60 years (Age)  60+ years (Age)  \
# count       2.201000e+03       2.201000e+03     2.201000e+03
# mean        5.005036e+05       2.180684e+06     2.238919e+06
# std         1.497804e+06       7.230462e+06     6.964383e+06
# min         9.740000e+02       1.136000e+03     5.580000e+02
# 25%         2.680200e+04       7.456200e+04     4.873000e+04
# 50%         1.979680e+05       5.724770e+05     6.554660e+05
# 75%         4.207280e+05       1.893504e+06     1.920381e+06
# max         1.345514e+07       6.407694e+07     5.612611e+07
#
#        Total Doses Administered
# count              4.403000e+03
# mean               3.202298e+06
# std                1.384048e+07
# min                0.000000e+00
# 25%                4.332250e+04
# 50%                2.667910e+05
# 75%                2.014314e+06
# max                1.796464e+08

# %%
jyothi_df2.head()
# Out:
#    Updated On  State  Total Individuals Vaccinated  Total Sessions Conducted  \
# 0  16/01/2021  India                       48276.0                    3455.0
# 1  17/01/2021  India                       58604.0                    8532.0
# 2  18/01/2021  India                       99449.0                   13611.0
# 3  19/01/2021  India                      195525.0                   17855.0
# 4  20/01/2021  India                      251280.0                   25472.0
#
#    Total Sites   First Dose Administered  Second Dose Administered  \
# 0        2957.0                  48276.0                       0.0
# 1        4954.0                  58604.0                       0.0
# 2        6583.0                  99449.0                       0.0
# 3        7951.0                 195525.0                       0.0
# 4       10504.0                 251280.0                       0.0
#
#    Male(Individuals Vaccinated)  Female(Individuals Vaccinated)  \
# 0                       23757.0                         24517.0
# 1                       27348.0                         31252.0
# 2                       41361.0                         58083.0
# 3                       81901.0                        113613.0
# 4                       98111.0                        153145.0
#
#    Transgender(Individuals Vaccinated)  Total Covaxin Administered  \
# 0                                  2.0                       579.0
# 1                                  4.0                       635.0
# 2                                  5.0                      1299.0
# 3                                 11.0                      3017.0
# 4                                 24.0                      3946.0
#
#    Total CoviShield Administered  AEFI  18-30 years (Age)  30-45 years (Age)  \
# 0                        47697.0   NaN                NaN                NaN
# 1                        57969.0   NaN                NaN                NaN
# 2                        98150.0   NaN                NaN                NaN
# 3                       192508.0   NaN                NaN                NaN
# 4                       247334.0   NaN                NaN                NaN
#
#    45-60 years (Age)  60+ years (Age)  Total Doses Administered
# 0                NaN              NaN                   48276.0
# 1                NaN              NaN                   58604.0
# 2                NaN              NaN                   99449.0
# 3                NaN              NaN                  195525.0
# 4                NaN              NaN                  251280.0

# %%
jyothi_df2.columns
# Out:
# Index(['Updated On', 'State', 'Total Individuals Vaccinated',
#        'Total Sessions Conducted', 'Total Sites ', 'First Dose Administered',
#        'Second Dose Administered', 'Male(Individuals Vaccinated)',
#        'Female(Individuals Vaccinated)', 'Transgender(Individuals Vaccinated)',
#        'Total Covaxin Administered', 'Total CoviShield Administered', 'AEFI',
#        '18-30 years (Age)', '30-45 years (Age)', '45-60 years (Age)',
#        '60+ years (Age)', 'Total Doses Administered'],
#       dtype='object')

# %%
# Get unique state values
unique_states = data['State'].unique()

# Print the unique state values
print(unique_states)

# Get the count of unique state values
num_unique_states = data['State'].nunique()

# Print the count of unique state values
print("Number of unique states:", num_unique_states)
# Out:
# ['India' 'Andaman and Nicobar Islands' 'Andhra Pradesh'
#  'Arunachal Pradesh' 'Assam' 'Bihar' 'Chandigarh' 'Chhattisgarh'
#  'Dadra and Nagar Haveli and Daman and Diu' 'Delhi' 'Goa' 'Gujarat'
#  'Haryana' 'Himachal Pradesh' 'Jammu and Kashmir' 'Jharkhand' 'Karnataka'
#  'Kerala' 'Ladakh' 'Lakshadweep' 'Madhya Pradesh' 'Maharashtra' 'Manipur'
#  'Meghalaya' 'Mizoram' 'Nagaland' 'Odisha' 'Puducherry' 'Punjab'
#  'Rajasthan' 'Sikkim' 'Tamil Nadu' 'Telangana' 'Tripura' 'Uttar Pradesh'
#  'Uttarakhand' 'West Bengal']
# Number of unique states: 37

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate


data = pd.read_csv(file_path)

# Calculate mean, median, and mode for the relevant columns
columns_of_interest = ['Total Individuals Vaccinated', 'Total Sessions Conducted', 'Total Sites ',
                       'First Dose Administered', 'Second Dose Administered', 'Male(Individuals Vaccinated)',
                       'Female(Individuals Vaccinated)', 'Transgender(Individuals Vaccinated)',
                       'Total Covaxin Administered', 'Total CoviShield Administered', 'AEFI',
                       '18-30 years (Age)', '30-45 years (Age)', '45-60 years (Age)',
                       '60+ years (Age)', 'Total Doses Administered']

central_tendency_measures = []
for column in columns_of_interest:
    mean = data[column].mean()
    median = data[column].median()
    mode = data[column].mode().iloc[0]  # Mode may have multiple values, so we select the first one
    central_tendency_measures.append([column, mean, median, mode])

# Display the tabulated output of central tendency measures
table_headers = ['Column', 'Mean', 'Median', 'Mode']
print(tabulate(central_tendency_measures, headers=table_headers, tablefmt='pretty'))
# Out:
# +-------------------------------------+--------------------+----------+--------+
# |               Column                |        Mean        |  Median  |  Mode  |
# +-------------------------------------+--------------------+----------+--------+
# |    Total Individuals Vaccinated     | 2767474.357483534  | 245544.0 | 807.0  |
# |      Total Sessions Conducted       | 236364.06132182604 | 11583.0  | 1000.0 |
# |             Total Sites             | 2417.3642970701794 |  581.0   |  13.0  |
# |       First Dose Administered       | 2751246.680445151  | 238803.0 | 807.0  |
# |      Second Dose Administered       | 533488.9157392686  | 34908.0  |  0.0   |
# |    Male(Individuals Vaccinated)     | 1447784.3595275949 | 118485.0 | 623.0  |
# |   Female(Individuals Vaccinated)    | 1319362.6879400408 | 118043.0 | 414.0  |
# | Transgender(Individuals Vaccinated) | 346.1841925959573  |   21.0   |  0.0   |
# |     Total Covaxin Administered      | 301327.25823302293 |  407.0   |  0.0   |
# |    Total CoviShield Administered    | 2963895.4973881445 | 257334.0 | 807.0  |
# |                AEFI                 | 998.6983189459337  |  273.0   |  1.0   |
# |          18-30 years (Age)          | 161939.56383462064 | 37497.0  | 125.0  |
# |          30-45 years (Age)          | 500503.6056338028  | 197968.0 | 1909.0 |
# |          45-60 years (Age)          | 2180684.0967741935 | 572477.0 | 9326.0 |
# |           60+ years (Age)           | 2238918.7810086324 | 655466.0 | 1989.0 |
# |      Total Doses Administered       | 3202298.2684533275 | 266791.0 |  0.0   |
# +-------------------------------------+--------------------+----------+--------+

# %%
measures = []
for column in columns_of_interest :
    column_data = jyothi_df2[column].dropna()
    data_range = column_data.max() - column_data.min()
    data_variance = column_data.var()
    data_std_dev = column_data.std()
    measures.append([column, data_range, data_variance, data_std_dev])

table_headers = ['Column', 'Range', 'Variance', 'Standard Deviation']
print(tabulate(measures, headers=table_headers, tablefmt='pretty'))
# Out:
# +-------------------------------------+-------------+--------------------+--------------------+
# |               Column                |    Range    |      Variance      | Standard Deviation |
# +-------------------------------------+-------------+--------------------+--------------------+
# |    Total Individuals Vaccinated     | 141132105.0 | 136910087490116.7  | 11700858.408258632 |
# |      Total Sessions Conducted       | 10786962.0  | 946577372122.3511  | 972922.0791627411  |
# |             Total Sites             |   73933.0   | 60203808.41473592  | 7759.111316042316  |
# |       First Dose Administered       | 141132105.0 | 136667205783591.34 | 11690475.002479212 |
# |      Second Dose Administered       | 40412424.0  | 6164122703615.216  |  2482765.13259213  |
# |    Male(Individuals Vaccinated)     | 74324379.0  | 37559049801530.43  | 6128543.856539695  |
# |   Female(Individuals Vaccinated)    | 66787919.0  | 31054281111879.58  |  5572636.81858773  |
# | Transgender(Individuals Vaccinated) |   19812.0   | 2270282.337487461  | 1506.7456114047457 |
# |     Total Covaxin Administered      | 18535310.0  | 1767007264698.0544 | 1329288.2549312073 |
# |    Total CoviShield Administered    | 163009209.0 | 163295670296214.25 | 12778719.430999894 |
# |                AEFI                 |   20459.0   | 8891184.054401716  | 2981.8088561143077 |
# |          18-30 years (Age)          |  7447361.0  | 330976178192.27155 | 575305.2912952144  |
# |          30-45 years (Age)          | 13454168.0  | 2243415527965.5166 | 1497803.5678838252 |
# |          45-60 years (Age)          | 64075805.0  | 52279584343720.75  |  7230462.2496574   |
# |           60+ years (Age)           | 56125556.0  | 48502634886062.48  | 6964383.3098173505 |
# |      Total Doses Administered       | 179646413.0 | 191558834647869.7  | 13840478.122083416 |
# +-------------------------------------+-------------+--------------------+--------------------+

# %%
coeff_of_var_measures = []
for column in columns_of_interest:
    column_data = jyothi_df2[column].dropna()
    data_std_dev = column_data.std()
    coeff_of_var = (data_std_dev / column_data.mean()) * 100
    coeff_of_var_measures.append([column, coeff_of_var])

table_headers = ['Column', 'Coefficient of Variation (%)']
print(tabulate(coeff_of_var_measures, headers=table_headers, tablefmt='pretty'))
# Out:
# +-------------------------------------+------------------------------+
# |               Column                | Coefficient of Variation (%) |
# +-------------------------------------+------------------------------+
# |    Total Individuals Vaccinated     |      422.7991625872995       |
# |      Total Sessions Conducted       |      411.6201395939124       |
# |             Total Sites             |      320.97401808433585      |
# |       First Dose Administered       |      424.91555139605646      |
# |      Second Dose Administered       |      465.3827023100755       |
# |    Male(Individuals Vaccinated)     |      423.3050188868879       |
# |   Female(Individuals Vaccinated)    |      422.37338296177296      |
# | Transgender(Individuals Vaccinated) |      435.2439087718014       |
# |     Total Covaxin Administered      |      441.1443766243145       |
# |    Total CoviShield Administered    |      431.1460860297135       |
# |                AEFI                 |      298.56952790923174      |
# |          18-30 years (Age)          |      355.2592570168584       |
# |          30-45 years (Age)          |      299.2592962416547       |
# |          45-60 years (Age)          |      331.5685321112379       |
# |           60+ years (Age)           |      311.06011387692666      |
# |      Total Doses Administered       |      432.2045281799501       |
# +-------------------------------------+------------------------------+

# %%
#Initialize a list to store IQR and quartiles measures
iqr_quartiles_measures = []

# Calculate IQR and quartiles for each numeric column
for column in columns_of_interest:
    column_data = jyothi_df2[column].dropna()
    q1 = column_data.quantile(0.25)
    q3 = column_data.quantile(0.75)
    data_iqr = q3 - q1
    iqr_quartiles_measures.append([column, data_iqr, q1, q3])

# Tabulate IQR and quartiles measures
table_headers = ['Column', 'IQR', 'Q1', 'Q3']
print(tabulate(iqr_quartiles_measures, headers=table_headers, tablefmt='pretty'))
# Out:
# +-------------------------------------+-----------+---------+-----------+
# |               Column                |    IQR    |   Q1    |    Q3     |
# +-------------------------------------+-----------+---------+-----------+
# |    Total Individuals Vaccinated     | 1723227.0 | 43518.5 | 1766745.5 |
# |      Total Sessions Conducted       | 147572.5  | 1930.0  | 149502.5  |
# |             Total Sites             |  1775.0   |  67.0   |  1842.0   |
# |       First Dose Administered       | 1671933.5 | 41469.5 | 1713403.0 |
# |      Second Dose Administered       | 333812.5  |  117.0  | 333929.5  |
# |    Male(Individuals Vaccinated)     | 921716.5  | 22100.5 | 943817.0  |
# |   Female(Individuals Vaccinated)    | 817891.0  | 20242.5 | 838133.5  |
# | Transgender(Individuals Vaccinated) |   231.0   |   2.0   |   233.0   |
# |     Total Covaxin Administered      | 173559.0  |   0.0   | 173559.0  |
# |    Total CoviShield Administered    | 1841342.5 | 45146.5 | 1886489.0 |
# |                AEFI                 |   547.0   |  88.0   |   635.0   |
# |          18-30 years (Age)          | 126455.0  | 5195.0  | 131650.0  |
# |          30-45 years (Age)          | 393926.0  | 26802.0 | 420728.0  |
# |          45-60 years (Age)          | 1818942.0 | 74562.0 | 1893504.0 |
# |           60+ years (Age)           | 1871651.0 | 48730.0 | 1920381.0 |
# |      Total Doses Administered       | 1970991.5 | 43322.5 | 2014314.0 |
# +-------------------------------------+-----------+---------+-----------+

# %%
# Calculate skewness and kurtosis for each numeric column
from scipy.stats import skew, kurtosis
# Initialize a list to store skewness and kurtosis measures
skew_kurtosis_measures = []
for column in columns_of_interest:
    column_data = jyothi_df2[column].dropna()
    data_skewness = skew(column_data)
    data_kurtosis = kurtosis(column_data)
    skew_kurtosis_measures.append([column, data_skewness, data_kurtosis])

# Tabulate skewness and kurtosis measures
table_headers = ['Column', 'Skewness', 'Kurtosis']
print(tabulate(skew_kurtosis_measures, headers=table_headers, tablefmt='pretty'))
# Out:
# +-------------------------------------+--------------------+--------------------+
# |               Column                |      Skewness      |      Kurtosis      |
# +-------------------------------------+--------------------+--------------------+
# |    Total Individuals Vaccinated     |  9.01875381243616  | 87.74676376196636  |
# |      Total Sessions Conducted       | 8.029531086552465  | 68.16727412898426  |
# |             Total Sites             | 6.3685150557811445 | 42.787440080360895 |
# |       First Dose Administered       | 9.042644318275517  |  88.1113308958791  |
# |      Second Dose Administered       | 10.859800759378906 |  135.943883421232  |
# |    Male(Individuals Vaccinated)     | 8.995230766385307  | 87.43322739716817  |
# |   Female(Individuals Vaccinated)    | 9.037686393452567  |  87.992702461302   |
# | Transgender(Individuals Vaccinated) |  9.45696658952008  | 97.52022467589197  |
# |     Total Covaxin Administered      |  9.40419914651598  | 98.60328719092675  |
# |    Total CoviShield Administered    | 9.247609418482412  | 93.05831571460219  |
# |                AEFI                 | 5.382351498900844  | 28.851605165215588 |
# |          18-30 years (Age)          |  8.38624974891339  | 80.48144844786317  |
# |          30-45 years (Age)          | 5.831369471778094  | 34.834761169360895 |
# |          45-60 years (Age)          | 6.808478090915387  | 48.21771064146729  |
# |           60+ years (Age)           | 6.154986521175607  | 39.05602149614595  |
# |      Total Doses Administered       | 9.331082388827319  | 95.04656083678319  |
# +-------------------------------------+--------------------+--------------------+

# %%
import matplotlib.pyplot as plt

# Sample data (replace this with your actual data)
total_individuals_vaccinated = 90187538.1243616  # Replace with actual value

# Pie chart data
labels = ['Vaccinated', 'Not Vaccinated']
sizes = [total_individuals_vaccinated, 100000000 - total_individuals_vaccinated]  # Assuming total population is 100 million
colors = ['#0ab', '#ccc']

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title("Total Individuals Vaccinated")
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data (replace this with your actual data)
total_sessions_conducted = 8029531.086552465  # Replace with actual value
total_covaxin_administered = 9404199.14651598  # Replace with actual value

# Pie chart for Total Sessions Conducted
plt.figure(figsize=(6, 6))
plt.pie([total_sessions_conducted, 10000000 - total_sessions_conducted], labels=['Conducted', 'Not Conducted'],
        colors=['#0ab', '#ccc'], autopct='%1.1f%%', startangle=140)
plt.title("Total Sessions Conducted")
plt.axis('equal')
plt.show()

# Pie chart for Total Covaxin Administered
plt.figure(figsize=(6, 6))
plt.pie([total_covaxin_administered, 10000000 - total_covaxin_administered], labels=['Administered', 'Not Administered'],
        colors=['#0ab', '#ccc'], autopct='%1.1f%%', startangle=140)
plt.title("Total Covaxin Administered")
plt.axis('equal')
plt.show()
