# %%
import pandas as pd

# Replace 'dataset.csv' with the actual file path of your CSV dataset
file_path = r'C:\Users\jyoth\OneDrive\Desktop\Mtech Sem3\Courses\Intro to DS\3\StatewiseTestingDetails.csv'

# Load the CSV dataset into a Pandas DataFrame
data = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to verify the data has been loaded
data.head()
# Out:
#          Date                        State  TotalSamples Negative  Positive
# 0  2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1  2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2  2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3  2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4  2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
jyothi_df3 = pd.read_csv(file_path)

# %%
jyothi_df3
# Out:
#              Date                        State  TotalSamples Negative  \
# 0      2020-04-17  Andaman and Nicobar Islands        1403.0     1210
# 1      2020-04-24  Andaman and Nicobar Islands        2679.0      NaN
# 2      2020-04-27  Andaman and Nicobar Islands        2848.0      NaN
# 3      2020-05-01  Andaman and Nicobar Islands        3754.0      NaN
# 4      2020-05-16  Andaman and Nicobar Islands        6677.0      NaN
# ...           ...                          ...           ...      ...
# 13295  2021-05-11                  West Bengal    11099069.0      NaN
# 13296  2021-05-12                  West Bengal    11168943.0      NaN
# 13297  2021-05-13                  West Bengal    11239416.0      NaN
# 13298  2021-05-14                  West Bengal    11309467.0      NaN
# 13299  2021-05-15                  West Bengal    11376030.0      NaN
#
#        Positive
# 0          12.0
# 1          27.0
# 2          33.0
# 3          33.0
# 4          33.0
# ...         ...
# ...

# %%
jyothi_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13300 entries, 0 to 13299
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          13300 non-null  object
#  1   State         13300 non-null  object
#  2   TotalSamples  13300 non-null  float64
#  3   Negative      6094 non-null   object
#  4   Positive      5435 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 519.7+ KB

# %%
jyothi_df3['Date'] = pd.to_datetime(jyothi_df3['Date'],format='%Y-%m-%d')

# %%
jyothi_df3.describe()
# Out:
#                                 Date  TotalSamples      Positive
# count                          13300  1.330000e+04  5.435000e+03
# mean   2020-10-27 20:48:47.639097856  3.739263e+06  5.225873e+04
# min              2020-04-01 00:00:00  5.800000e+01  0.000000e+00
# 25%              2020-07-21 00:00:00  1.137128e+05  4.865000e+02
# 50%              2020-10-27 00:00:00  6.053420e+05  4.176000e+03
# 75%              2021-02-05 00:00:00  5.348355e+06  3.294050e+04
# max              2021-05-15 00:00:00  4.442745e+07  1.638961e+06
# std                              NaN  6.050518e+06  1.647803e+05

# %%
jyothi_df3.head()
# Out:
#         Date                        State  TotalSamples Negative  Positive
# 0 2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1 2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2 2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3 2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4 2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0

# %%
jyothi_df3.columns
# Out:
# Index(['Date', 'State', 'TotalSamples', 'Negative', 'Positive'], dtype='object')

# %%
# Get unique state values
unique_states = data['State'].unique()

# Print the unique state values
print(unique_states)

# Get the count of unique state values
num_unique_states = data['State'].nunique()

# Print the count of unique state values
print("Number of unique states:", num_unique_states)
# Out:
# ['Andaman and Nicobar Islands' 'Andhra Pradesh' 'Arunachal Pradesh'
#  'Assam' 'Bihar' 'Chandigarh' 'Chhattisgarh'
#  'Dadra and Nagar Haveli and Daman and Diu' 'Delhi' 'Goa' 'Gujarat'
#  'Haryana' 'Himachal Pradesh' 'Jammu and Kashmir' 'Jharkhand' 'Karnataka'
#  'Kerala' 'Ladakh' 'Lakshadweep' 'Madhya Pradesh' 'Maharashtra' 'Manipur'
#  'Meghalaya' 'Mizoram' 'Nagaland' 'Odisha' 'Puducherry' 'Punjab'
#  'Rajasthan' 'Sikkim' 'Tamil Nadu' 'Telangana' 'Tripura' 'Uttar Pradesh'
#  'Uttarakhand' 'West Bengal']
# Number of unique states: 36

# %%
jyothi_df3 = pd.read_csv(file_path)

# Clean the dataset: Convert columns to numeric and handle missing values
numeric_columns = ['TotalSamples', 'Negative', 'Positive']
jyothi_df3[numeric_columns] = jyothi_df3[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Calculate central tendency measures for numeric columns
central_tendency_measures = {}
for column in numeric_columns:
    mean = jyothi_df3[column].mean()
    median = jyothi_df3[column].median()
    mode = jyothi_df3[column].mode().iloc[0] if len(jyothi_df3[column].mode()) > 0 else None
    central_tendency_measures[column] = {'Mean': mean, 'Median': median, 'Mode': mode}

# Display the calculated central tendency measures
for column, measures in central_tendency_measures.items():
    print(f"Central Tendency Measures for '{column}':")
    print(f"Mean: {measures['Mean']:.2f}")
    print(f"Median: {measures['Median']:.2f}")
    print(f"Mode: {measures['Mode']}")
    print()
# Out:
# Central Tendency Measures for 'TotalSamples':
# Mean: 3739263.16
# Median: 605342.00
# Mode: 183.0
#
# Central Tendency Measures for 'Negative':
# Mean: 1422657.82
# Median: 344351.00
# Mode: 219.0
#
# Central Tendency Measures for 'Positive':
# Mean: 52258.73
# Median: 4176.00
# Mode: 1.0

# %%
import pandas as pd
from tabulate import tabulate


jyothi_df3 = pd.read_csv(file_path)

# Clean the dataset: Convert columns to numeric and handle missing values
numeric_columns = ['TotalSamples', 'Negative', 'Positive']
jyothi_df3[numeric_columns] = jyothi_df3[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Calculate central tendency measures for numeric columns
central_tendency_measures = []
for column in numeric_columns:
    mean = jyothi_df3[column].mean()
    median = jyothi_df3[column].median()
    mode = jyothi_df3[column].mode().iloc[0] if len(jyothi_df3[column].mode()) > 0 else None
    central_tendency_measures.append([column, mean, median, mode])

# Tabulate the central tendency measures
table_headers = ['Column', 'Mean', 'Median', 'Mode']
print(tabulate(central_tendency_measures, headers=table_headers, tablefmt='pretty'))
# Out:
# +--------------+--------------------+----------+-------+
# |    Column    |        Mean        |  Median  | Mode  |
# +--------------+--------------------+----------+-------+
# | TotalSamples | 3739263.1630827067 | 605342.0 | 183.0 |
# |   Negative   | 1422657.824881011  | 344351.0 | 219.0 |
# |   Positive   | 52258.72769089237  |  4176.0  |  1.0  |
# +--------------+--------------------+----------+-------+

# %%
measures = []
for column in numeric_columns:
    column_data = jyothi_df3[column].dropna()
    data_range = column_data.max() - column_data.min()
    data_variance = column_data.var()
    data_std_dev = column_data.std()
    measures.append([column, data_range, data_variance, data_std_dev])

table_headers = ['Column', 'Range', 'Variance', 'Standard Deviation']
print(tabulate(measures, headers=table_headers, tablefmt='pretty'))
# Out:
# +--------------+------------+--------------------+--------------------+
# |    Column    |   Range    |      Variance      | Standard Deviation |
# +--------------+------------+--------------------+--------------------+
# | TotalSamples | 44427389.0 | 36608768174483.945 | 6050518.008772798  |
# |   Negative   | 16469435.0 | 6315719875526.553  | 2513109.6027683616 |
# |   Positive   | 1638961.0  | 27152535164.59459  | 164780.26327383565 |
# +--------------+------------+--------------------+--------------------+

# %%
coeff_of_var_measures = []
for column in numeric_columns:
    column_data = jyothi_df3[column].dropna()
    data_std_dev = column_data.std()
    coeff_of_var = (data_std_dev / column_data.mean()) * 100
    coeff_of_var_measures.append([column, coeff_of_var])

table_headers = ['Column', 'Coefficient of Variation (%)']
print(tabulate(coeff_of_var_measures, headers=table_headers, tablefmt='pretty'))
# Out:
# +--------------+------------------------------+
# |    Column    | Coefficient of Variation (%) |
# +--------------+------------------------------+
# | TotalSamples |       161.81043550261        |
# |   Negative   |      176.6489143641096       |
# |   Positive   |      315.31625539852837      |
# +--------------+------------------------------+

# %%
import pandas as pd
import numpy as np

# Load your dataset into a DataFrame named jyothi_df3

# List of numeric columns in the dataset
numeric_columns = ['TotalSamples', 'Negative', 'Positive']

# Initialize a list to store IQR and quartiles measures
iqr_quartiles_measures = []

# Calculate IQR and quartiles for each numeric column
for column in numeric_columns:
    column_data = jyothi_df3[column].dropna()
    q1 = column_data.quantile(0.25)
    q3 = column_data.quantile(0.75)
    data_iqr = q3 - q1
    iqr_quartiles_measures.append([column, data_iqr, q1, q3])

# Tabulate IQR and quartiles measures
table_headers = ['Column', 'IQR', 'Q1', 'Q3']
print(tabulate(iqr_quartiles_measures, headers=table_headers, tablefmt='pretty'))
# Out:
# +--------------+------------+-----------+-----------+
# |    Column    |    IQR     |    Q1     |    Q3     |
# +--------------+------------+-----------+-----------+
# | TotalSamples | 5234642.25 | 113712.75 | 5348355.0 |
# |   Negative   | 1469541.0  |  56440.0  | 1525981.0 |
# |   Positive   |  32454.0   |   486.5   |  32940.5  |
# +--------------+------------+-----------+-----------+

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis

# Load your dataset into a DataFrame named jyothi_df3

# List of numeric columns in the dataset
numeric_columns = ['TotalSamples', 'Negative', 'Positive']

# Initialize a list to store skewness and kurtosis measures
skew_kurtosis_measures = []

# Calculate skewness and kurtosis for each numeric column
for column in numeric_columns:
    column_data = jyothi_df3[column].dropna()
    data_skewness = skew(column_data)
    data_kurtosis = kurtosis(column_data)
    skew_kurtosis_measures.append([column, data_skewness, data_kurtosis])

# Tabulate skewness and kurtosis measures
table_headers = ['Column', 'Skewness', 'Kurtosis']
print(tabulate(skew_kurtosis_measures, headers=table_headers, tablefmt='pretty'))
# Out:
# +--------------+--------------------+--------------------+
# |    Column    |      Skewness      |      Kurtosis      |
# +--------------+--------------------+--------------------+
# | TotalSamples | 2.5021644347483685 | 7.577962525138126  |
# |   Negative   | 2.9146579399740205 | 10.166607476706185 |
# |   Positive   | 5.759160538772945  | 38.55507012566238  |
# +--------------+--------------------+--------------------+

# %%
plt.figure(figsize=(7, 6))
sns.barplot(x='State', y='TotalSamples', data=jyothi_df3)
plt.title('Total Samples by State')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 6))
sns.barplot(x='State', y='Positive', data=jyothi_df3)
plt.title('Positive Cases by State')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\jyoth\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# c:\Users\jyoth\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\nanfunctions.py:1384: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(

# %%
plt.figure(figsize=(7, 6))
sns.barplot(x='State', y='Negative', data=jyothi_df3)
plt.title('Negative Cases by State')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\jyoth\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# c:\Users\jyoth\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\nanfunctions.py:1384: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(

# %%
plt.figure(figsize=(5, 4))
sns.histplot(jyothi_df3['TotalSamples'], bins=20, kde=True)
plt.title('Total Samples Histogram')
plt.xlabel('Total Samples')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 4))
sns.histplot(jyothi_df3['Positive'], bins=20, kde=True)
plt.title('Positive Cases Histogram')
plt.xlabel('Positive Cases')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 4))
sns.histplot(jyothi_df3['Negative'], bins=20, kde=True)
plt.title('Negative Cases Histogram')
plt.xlabel('Negative Cases')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 6))
sns.boxplot(x='State', y='TotalSamples', data=jyothi_df3)
plt.title('Total Samples Box Plot')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 6))
sns.boxplot(x='State', y='Positive', data=jyothi_df3)
plt.title('Positive Cases Box Plot')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

plt.figure(figsize=(7, 6))
sns.boxplot(x='State', y='Negative', data=jyothi_df3)
plt.title('Negative Cases Box Plot')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.scatterplot(x='TotalSamples', y='Positive', data=jyothi_df3)
plt.title('Scatter Plot: Total Samples vs Positive Cases')
plt.xlabel('Total Samples')
plt.ylabel('Positive Cases')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.scatterplot(x='TotalSamples', y='Positive', data=jyothi_df3)
plt.title('Scatter Plot: Total Samples vs Positive Cases')
plt.xlabel('Total Samples')
plt.ylabel('Positive Cases')
plt.tight_layout()
plt.show()

plt.figure(figsize=(5, 3))
sns.scatterplot(x='TotalSamples', y='Negative', data=jyothi_df3)
plt.title('Scatter Plot: Total Samples vs Negative Cases')
plt.xlabel('Total Samples')
plt.ylabel('Negative Cases')
plt.tight_layout()
plt.show()

# %%
sns.pairplot(jyothi_df3[['TotalSamples', 'Positive', 'Negative']])
plt.suptitle('Pair Plot: Total Samples, Positive Cases, Negative Cases', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\jyoth\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\jyoth\AppData\Local\Temp\ipykernel_17340\2654173521.py:3: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
sns.pairplot(jyothi_df3[['TotalSamples', 'Positive']])
plt.suptitle('Pair Plot: Total Samples, Positive Cases', y=1.02)
plt.tight_layout()
plt.show()

sns.pairplot(jyothi_df3[['TotalSamples', 'Negative']])
plt.suptitle('Pair Plot: Total Samples, Negative Cases', y=1.02)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\jyoth\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\jyoth\AppData\Local\Temp\ipykernel_17340\1858470876.py:3: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# c:\Users\jyoth\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\jyoth\AppData\Local\Temp\ipykernel_17340\1858470876.py:8: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
plt.figure(figsize=(5, 3))
covariance_matrix = jyothi_df3.select_dtypes(include=np.number).cov()
sns.heatmap(covariance_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Covariance Matrix Heatmap (Entire Data)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5,3))
covariance_matrix = jyothi_df3[jyothi_df3['Positive'].notnull()].select_dtypes(include=np.number).cov()
sns.heatmap(covariance_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Covariance Matrix Heatmap (Positive Cases)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 3))
correlation_matrix = jyothi_df3.select_dtypes(include=np.number).corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix Heatmap (Entire Data)')
plt.tight_layout()
plt.show()
